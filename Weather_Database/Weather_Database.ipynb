# %% [markdown]
# # Weather Database

# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %% [markdown]
# ## Retrieve Weather Data

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 729

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | miranorte
# City not found. Skipping
# Processing Record 3 of Set 1 | kaeo
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | faanui
# Processing Record 6 of Set 1 | nguiu
# City not found. Skipping
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | saldanha
# Processing Record 9 of Set 1 | san patricio
# Processing Record 10 of Set 1 | cherskiy
# Processing Record 11 of Set 1 | belushya guba
# City not found. Skipping
# Processing Record 12 of Set 1 | east london
# Processing Record 13 of Set 1 | pauini
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | qarayeri
# Processing Record 18 of Set 1 | hammerfest
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | kuusamo
# Processing Record 21 of Set 1 | gravelbourg
# Processing Record 22 of Set 1 | sao joao da barra
# Processing Record 23 of Set 1 | ilulissat
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | sistranda
# Processing Record 26 of Set 1 | koumac
# Processing Record 27 of Set 1 | siavonga
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | klaksvik
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | la reforma
# Processing Record 33 of Set 1 | pevek
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | xining
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | sovetskaya gavan
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping
# Processing Record 39 of Set 1 | castro
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | talcahuano
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping
# Processing Record 43 of Set 1 | karkaralinsk
# City not found. Skipping
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | san cristobal
# Processing Record 46 of Set 1 | kluang
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | safwah
# City not found. Skipping
# Processing Record 49 of Set 1 | mishan
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | prince rupert
# Processing Record 3 of Set 2 | aykhal
# Processing Record 4 of Set 2 | lasa
# Processing Record 5 of Set 2 | beringovskiy
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | norman wells
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | gat
# Processing Record 10 of Set 2 | byron bay
# Processing Record 11 of Set 2 | rikitea
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | bako
# Processing Record 14 of Set 2 | yuanping
# Processing Record 15 of Set 2 | port augusta
# Processing Record 16 of Set 2 | lasem
# Processing Record 17 of Set 2 | pimentel
# Processing Record 18 of Set 2 | kodiak
# Processing Record 19 of Set 2 | collie
# Processing Record 20 of Set 2 | jiddah
# City not found. Skipping
# Processing Record 21 of Set 2 | carutapera
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | lorengau
# Processing Record 24 of Set 2 | virden
# Processing Record 25 of Set 2 | port-cartier
# Processing Record 26 of Set 2 | leningradskiy
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | arman
# Processing Record 29 of Set 2 | port hedland
# Processing Record 30 of Set 2 | okha
# Processing Record 31 of Set 2 | majene
# Processing Record 32 of Set 2 | anadyr
# Processing Record 33 of Set 2 | kloulklubed
# Processing Record 34 of Set 2 | nizhneyansk
# City not found. Skipping
# Processing Record 35 of Set 2 | chala
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping
# Processing Record 38 of Set 2 | narsaq
# Processing Record 39 of Set 2 | bonfim
# Processing Record 40 of Set 2 | adre
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | sena madureira
# Processing Record 43 of Set 2 | iqaluit
# Processing Record 44 of Set 2 | vaitupu
# City not found. Skipping
# Processing Record 45 of Set 2 | harper
# Processing Record 46 of Set 2 | sao pedro do sul
# Processing Record 47 of Set 2 | verkhoyansk
# Processing Record 48 of Set 2 | kachug
# Processing Record 49 of Set 2 | carahue
# Processing Record 50 of Set 2 | pathein
# Processing Record 1 of Set 3 | mar del plata
# Processing Record 2 of Set 3 | plettenberg bay
# Processing Record 3 of Set 3 | barrow
# Processing Record 4 of Set 3 | padang
# Processing Record 5 of Set 3 | hobart
# Processing Record 6 of Set 3 | richards bay
# Processing Record 7 of Set 3 | lumeje
# Processing Record 8 of Set 3 | hamilton
# Processing Record 9 of Set 3 | marcona
# City not found. Skipping
# Processing Record 10 of Set 3 | ribeira grande
# Processing Record 11 of Set 3 | toliary
# City not found. Skipping
# Processing Record 12 of Set 3 | cidreira
# Processing Record 13 of Set 3 | north bend
# Processing Record 14 of Set 3 | iranshahr
# Processing Record 15 of Set 3 | road town
# Processing Record 16 of Set 3 | laguna
# Processing Record 17 of Set 3 | new norfolk
# Processing Record 18 of Set 3 | vila velha
# Processing Record 19 of Set 3 | port elizabeth
# Processing Record 20 of Set 3 | robertson
# Processing Record 21 of Set 3 | touros
# Processing Record 22 of Set 3 | abaza
# Processing Record 23 of Set 3 | okakarara
# Processing Record 24 of Set 3 | port huron
# Processing Record 25 of Set 3 | taolanaro
# City not found. Skipping
# Processing Record 26 of Set 3 | upernavik
# Processing Record 27 of Set 3 | vardo
# Processing Record 28 of Set 3 | lakatoro
# Processing Record 29 of Set 3 | half moon bay
# Processing Record 30 of Set 3 | dikson
# Processing Record 31 of Set 3 | bethel
# Processing Record 32 of Set 3 | chokurdakh
# Processing Record 33 of Set 3 | hansi
# Processing Record 34 of Set 3 | sciacca
# Processing Record 35 of Set 3 | olinda
# Processing Record 36 of Set 3 | riyadh
# Processing Record 37 of Set 3 | muroto
# Processing Record 38 of Set 3 | derzhavinsk
# Processing Record 39 of Set 3 | beruni
# City not found. Skipping
# Processing Record 40 of Set 3 | alyangula
# Processing Record 41 of Set 3 | arlit
# Processing Record 42 of Set 3 | khatanga
# Processing Record 43 of Set 3 | carnarvon
# Processing Record 44 of Set 3 | lebu
# Processing Record 45 of Set 3 | geraldton
# Processing Record 46 of Set 3 | tuatapere
# Processing Record 47 of Set 3 | rabo de peixe
# Processing Record 48 of Set 3 | tiksi
# Processing Record 49 of Set 3 | foumban
# Processing Record 50 of Set 3 | saint george
# Processing Record 1 of Set 4 | kerteh
# City not found. Skipping
# Processing Record 2 of Set 4 | praia da vitoria
# Processing Record 3 of Set 4 | kapenguria
# Processing Record 4 of Set 4 | roma
# Processing Record 5 of Set 4 | kuching
# Processing Record 6 of Set 4 | bengkulu
# Processing Record 7 of Set 4 | takab
# Processing Record 8 of Set 4 | ratnagiri
# Processing Record 9 of Set 4 | bubaque
# Processing Record 10 of Set 4 | sadiqabad
# Processing Record 11 of Set 4 | hafizabad
# Processing Record 12 of Set 4 | avarua
# Processing Record 13 of Set 4 | valente
# Processing Record 14 of Set 4 | mehamn
# Processing Record 15 of Set 4 | auki
# Processing Record 16 of Set 4 | haines junction
# Processing Record 17 of Set 4 | thyboron
# Processing Record 18 of Set 4 | bereznik
# Processing Record 19 of Set 4 | matagami
# Processing Record 20 of Set 4 | vao
# Processing Record 21 of Set 4 | bandarbeyla
# Processing Record 22 of Set 4 | kuytun
# Processing Record 23 of Set 4 | villarrica
# Processing Record 24 of Set 4 | fortuna
# Processing Record 25 of Set 4 | namibe
# Processing Record 26 of Set 4 | owando
# Processing Record 27 of Set 4 | nanortalik
# Processing Record 28 of Set 4 | souillac
# Processing Record 29 of Set 4 | gambela
# Processing Record 30 of Set 4 | singkang
# Processing Record 31 of Set 4 | dzhebariki-khaya
# Processing Record 32 of Set 4 | yellowknife
# Processing Record 33 of Set 4 | dunn
# Processing Record 34 of Set 4 | kindersley
# Processing Record 35 of Set 4 | guane
# Processing Record 36 of Set 4 | yumen
# Processing Record 37 of Set 4 | port alfred
# Processing Record 38 of Set 4 | skagen
# Processing Record 39 of Set 4 | qinhuangdao
# Processing Record 40 of Set 4 | albany
# Processing Record 41 of Set 4 | vangaindrano
# Processing Record 42 of Set 4 | provideniya
# Processing Record 43 of Set 4 | nova soure
# Processing Record 44 of Set 4 | grand centre
# City not found. Skipping
# Processing Record 45 of Set 4 | fairbanks
# Processing Record 46 of Set 4 | doctor pedro p. pena
# City not found. Skipping
# Processing Record 47 of Set 4 | ponta do sol
# Processing Record 48 of Set 4 | quatre cocos
# Processing Record 49 of Set 4 | desa
# Processing Record 50 of Set 4 | kahului
# Processing Record 1 of Set 5 | jiwani
# Processing Record 2 of Set 5 | ozernovskiy
# Processing Record 3 of Set 5 | talnakh
# Processing Record 4 of Set 5 | constitucion
# Processing Record 5 of Set 5 | lieksa
# Processing Record 6 of Set 5 | sicamous
# Processing Record 7 of Set 5 | acarau
# Processing Record 8 of Set 5 | dalvik
# Processing Record 9 of Set 5 | les cayes
# Processing Record 10 of Set 5 | sur
# Processing Record 11 of Set 5 | rio grande
# Processing Record 12 of Set 5 | esperance
# Processing Record 13 of Set 5 | omboue
# Processing Record 14 of Set 5 | poum
# Processing Record 15 of Set 5 | itoman
# Processing Record 16 of Set 5 | labuhan
# Processing Record 17 of Set 5 | pitsunda
# Processing Record 18 of Set 5 | tahta
# Processing Record 19 of Set 5 | amderma
# City not found. Skipping
# Processing Record 20 of Set 5 | tumannyy
# City not found. Skipping
# Processing Record 21 of Set 5 | brae
# Processing Record 22 of Set 5 | manokwari
# Processing Record 23 of Set 5 | zalantun
# Processing Record 24 of Set 5 | bachaquero
# Processing Record 25 of Set 5 | chimbote
# Processing Record 26 of Set 5 | aflu
# City not found. Skipping
# Processing Record 27 of Set 5 | santa rosa
# Processing Record 28 of Set 5 | campos do jordao
# Processing Record 29 of Set 5 | suntar
# Processing Record 30 of Set 5 | miranda
# Processing Record 31 of Set 5 | kadykchan
# City not found. Skipping
# Processing Record 32 of Set 5 | kirksville
# Processing Record 33 of Set 5 | koygorodok
# Processing Record 34 of Set 5 | tsihombe
# City not found. Skipping
# Processing Record 35 of Set 5 | kysyl-syr
# Processing Record 36 of Set 5 | kulykivka
# Processing Record 37 of Set 5 | olkhovka
# Processing Record 38 of Set 5 | omsukchan
# Processing Record 39 of Set 5 | bilma
# Processing Record 40 of Set 5 | clyde river
# Processing Record 41 of Set 5 | ha noi
# Processing Record 42 of Set 5 | inirida
# Processing Record 43 of Set 5 | shelburne
# Processing Record 44 of Set 5 | luderitz
# Processing Record 45 of Set 5 | greensburg
# Processing Record 46 of Set 5 | charlestown
# Processing Record 47 of Set 5 | andros town
# Processing Record 48 of Set 5 | mana
# Processing Record 49 of Set 5 | mount gambier
# Processing Record 50 of Set 5 | lavrentiya
# Processing Record 1 of Set 6 | bredasdorp
# Processing Record 2 of Set 6 | cockburn harbour
# City not found. Skipping
# Processing Record 3 of Set 6 | adjumani
# Processing Record 4 of Set 6 | annau
# Processing Record 5 of Set 6 | banda aceh
# Processing Record 6 of Set 6 | merauke
# Processing Record 7 of Set 6 | houma
# Processing Record 8 of Set 6 | pangody
# Processing Record 9 of Set 6 | ketchikan
# Processing Record 10 of Set 6 | torbay
# Processing Record 11 of Set 6 | samarai
# Processing Record 12 of Set 6 | samusu
# City not found. Skipping
# Processing Record 13 of Set 6 | shaunavon
# Processing Record 14 of Set 6 | nome
# Processing Record 15 of Set 6 | sioux lookout
# Processing Record 16 of Set 6 | gulshat
# City not found. Skipping
# Processing Record 17 of Set 6 | caravelas
# Processing Record 18 of Set 6 | sharqpur
# Processing Record 19 of Set 6 | soledad
# Processing Record 20 of Set 6 | cabedelo
# Processing Record 21 of Set 6 | kamenskoye
# City not found. Skipping
# Processing Record 22 of Set 6 | port blair
# Processing Record 23 of Set 6 | tarudant
# City not found. Skipping
# Processing Record 24 of Set 6 | kavieng
# Processing Record 25 of Set 6 | isabela
# Processing Record 26 of Set 6 | svetlogorsk
# Processing Record 27 of Set 6 | ossora
# Processing Record 28 of Set 6 | sitka
# Processing Record 29 of Set 6 | parabel
# Processing Record 30 of Set 6 | codrington
# Processing Record 31 of Set 6 | lompoc
# Processing Record 32 of Set 6 | esterhazy
# Processing Record 33 of Set 6 | savannah bight
# Processing Record 34 of Set 6 | sinnamary
# Processing Record 35 of Set 6 | arvika
# Processing Record 36 of Set 6 | linhai
# Processing Record 37 of Set 6 | marsh harbour
# Processing Record 38 of Set 6 | blagoveshchenka
# Processing Record 39 of Set 6 | ust-nera
# Processing Record 40 of Set 6 | pisco
# Processing Record 41 of Set 6 | uray
# Processing Record 42 of Set 6 | seymchan
# Processing Record 43 of Set 6 | varena
# Processing Record 44 of Set 6 | alofi
# Processing Record 45 of Set 6 | dandong
# Processing Record 46 of Set 6 | saskylakh
# Processing Record 47 of Set 6 | flinders
# Processing Record 48 of Set 6 | taburi
# City not found. Skipping
# Processing Record 49 of Set 6 | lalomanu
# City not found. Skipping
# Processing Record 50 of Set 6 | barbar
# City not found. Skipping
# Processing Record 1 of Set 7 | maragheh
# Processing Record 2 of Set 7 | nanakuli
# Processing Record 3 of Set 7 | mineiros
# Processing Record 4 of Set 7 | kodinsk
# Processing Record 5 of Set 7 | siderno
# Processing Record 6 of Set 7 | mercedes
# Processing Record 7 of Set 7 | gondar
# Processing Record 8 of Set 7 | louisbourg
# City not found. Skipping
# Processing Record 9 of Set 7 | hudson bay
# Processing Record 10 of Set 7 | noumea
# Processing Record 11 of Set 7 | hambantota
# Processing Record 12 of Set 7 | vaitape
# Processing Record 13 of Set 7 | russell
# Processing Record 14 of Set 7 | puerto baquerizo moreno
# Processing Record 15 of Set 7 | shimanovsk
# Processing Record 16 of Set 7 | krasnyy chikoy
# Processing Record 17 of Set 7 | cabo san lucas
# Processing Record 18 of Set 7 | shipitsyno
# Processing Record 19 of Set 7 | bambous virieux
# Processing Record 20 of Set 7 | kruisfontein
# Processing Record 21 of Set 7 | xinxiang
# Processing Record 22 of Set 7 | shimoda
# Processing Record 23 of Set 7 | dingle
# Processing Record 24 of Set 7 | saleaula
# City not found. Skipping
# Processing Record 25 of Set 7 | barra patuca
# Processing Record 26 of Set 7 | ihosy
# Processing Record 27 of Set 7 | grand gaube
# Processing Record 28 of Set 7 | husavik
# Processing Record 29 of Set 7 | nelson bay
# Processing Record 30 of Set 7 | yerbogachen
# Processing Record 31 of Set 7 | srednekolymsk
# Processing Record 32 of Set 7 | urusha
# Processing Record 33 of Set 7 | kununurra
# Processing Record 34 of Set 7 | nova olimpia
# Processing Record 35 of Set 7 | rio gallegos
# Processing Record 36 of Set 7 | ostrovnoy
# Processing Record 37 of Set 7 | mirabad
# Processing Record 38 of Set 7 | nuuk
# Processing Record 39 of Set 7 | uzventis
# Processing Record 40 of Set 7 | gravdal
# Processing Record 41 of Set 7 | buala
# Processing Record 42 of Set 7 | chapais
# Processing Record 43 of Set 7 | bien hoa
# Processing Record 44 of Set 7 | babu
# Processing Record 45 of Set 7 | gewane
# Processing Record 46 of Set 7 | malwan
# City not found. Skipping
# Processing Record 47 of Set 7 | gayny
# Processing Record 48 of Set 7 | miramar
# Processing Record 49 of Set 7 | hovd
# Processing Record 50 of Set 7 | ust-kuyga
# Processing Record 1 of Set 8 | warqla
# City not found. Skipping
# Processing Record 2 of Set 8 | paro
# Processing Record 3 of Set 8 | jaipur hat
# City not found. Skipping
# Processing Record 4 of Set 8 | opuwo
# Processing Record 5 of Set 8 | muros
# Processing Record 6 of Set 8 | birjand
# Processing Record 7 of Set 8 | mount pleasant
# Processing Record 8 of Set 8 | eregli
# Processing Record 9 of Set 8 | phangnga
# Processing Record 10 of Set 8 | san-pedro
# Processing Record 11 of Set 8 | san policarpo
# Processing Record 12 of Set 8 | mayo
# Processing Record 13 of Set 8 | dongying
# Processing Record 14 of Set 8 | troitskoye
# Processing Record 15 of Set 8 | bargal
# City not found. Skipping
# Processing Record 16 of Set 8 | cerrito
# Processing Record 17 of Set 8 | bilibino
# Processing Record 18 of Set 8 | demyansk
# Processing Record 19 of Set 8 | laurinburg
# Processing Record 20 of Set 8 | tambul
# City not found. Skipping
# Processing Record 21 of Set 8 | grants pass
# Processing Record 22 of Set 8 | berbera
# Processing Record 23 of Set 8 | kandrian
# Processing Record 24 of Set 8 | kirakira
# Processing Record 25 of Set 8 | kontagora
# Processing Record 26 of Set 8 | makinsk
# Processing Record 27 of Set 8 | nhulunbuy
# Processing Record 28 of Set 8 | cayenne
# Processing Record 29 of Set 8 | palabuhanratu
# City not found. Skipping
# Processing Record 30 of Set 8 | karratha
# Processing Record 31 of Set 8 | cairns
# Processing Record 32 of Set 8 | kaitangata
# Processing Record 33 of Set 8 | iquitos
# Processing Record 34 of Set 8 | roald
# Processing Record 35 of Set 8 | jilmah
# City not found. Skipping
# Processing Record 36 of Set 8 | okhotsk
# Processing Record 37 of Set 8 | burnie
# Processing Record 38 of Set 8 | galle
# Processing Record 39 of Set 8 | esil
# Processing Record 40 of Set 8 | lagoa
# Processing Record 41 of Set 8 | isiro
# Processing Record 42 of Set 8 | xinglongshan
# Processing Record 43 of Set 8 | port lincoln
# Processing Record 44 of Set 8 | abu samrah
# Processing Record 45 of Set 8 | los llanos de aridane
# Processing Record 46 of Set 8 | asyut
# Processing Record 47 of Set 8 | shankargarh
# Processing Record 48 of Set 8 | asifabad
# Processing Record 49 of Set 8 | westport
# Processing Record 50 of Set 8 | seminole
# Processing Record 1 of Set 9 | antofagasta
# Processing Record 2 of Set 9 | morros
# Processing Record 3 of Set 9 | moroni
# Processing Record 4 of Set 9 | gorahun
# Processing Record 5 of Set 9 | baruun-urt
# Processing Record 6 of Set 9 | cockburn town
# Processing Record 7 of Set 9 | champerico
# Processing Record 8 of Set 9 | tabiauea
# City not found. Skipping
# Processing Record 9 of Set 9 | mys shmidta
# City not found. Skipping
# Processing Record 10 of Set 9 | itarema
# Processing Record 11 of Set 9 | khandbari
# Processing Record 12 of Set 9 | benxi
# Processing Record 13 of Set 9 | coihaique
# Processing Record 14 of Set 9 | nurota
# Processing Record 15 of Set 9 | ponta delgada
# Processing Record 16 of Set 9 | joacaba
# Processing Record 17 of Set 9 | miri
# Processing Record 18 of Set 9 | atikokan
# Processing Record 19 of Set 9 | kirkwood
# Processing Record 20 of Set 9 | saint-augustin
# Processing Record 21 of Set 9 | caceres
# Processing Record 22 of Set 9 | angoram
# Processing Record 23 of Set 9 | dukat
# Processing Record 24 of Set 9 | trairi
# Processing Record 25 of Set 9 | kerema
# Processing Record 26 of Set 9 | ponferrada
# Processing Record 27 of Set 9 | lata
# Processing Record 28 of Set 9 | galeana
# Processing Record 29 of Set 9 | ishigaki
# Processing Record 30 of Set 9 | rosarito
# Processing Record 31 of Set 9 | trinidad
# Processing Record 32 of Set 9 | nemuro
# Processing Record 33 of Set 9 | uusikaupunki
# Processing Record 34 of Set 9 | montepuez
# Processing Record 35 of Set 9 | vila franca do campo
# Processing Record 36 of Set 9 | chuy
# Processing Record 37 of Set 9 | bagotville
# Processing Record 38 of Set 9 | lanxi
# Processing Record 39 of Set 9 | saint-paul
# Processing Record 40 of Set 9 | seoni
# Processing Record 41 of Set 9 | xiaoweizhai
# Processing Record 42 of Set 9 | xuzhou
# Processing Record 43 of Set 9 | sorvag
# City not found. Skipping
# Processing Record 44 of Set 9 | hasaki
# Processing Record 45 of Set 9 | budureasa
# Processing Record 46 of Set 9 | nador
# Processing Record 47 of Set 9 | linhares
# Processing Record 48 of Set 9 | jieshi
# Processing Record 49 of Set 9 | pasni
# Processing Record 50 of Set 9 | san andres
# Processing Record 1 of Set 10 | rameshki
# Processing Record 2 of Set 10 | abnub
# Processing Record 3 of Set 10 | katsuura
# Processing Record 4 of Set 10 | dunedin
# Processing Record 5 of Set 10 | aitape
# Processing Record 6 of Set 10 | carauari
# Processing Record 7 of Set 10 | hakvik
# City not found. Skipping
# Processing Record 8 of Set 10 | beya
# Processing Record 9 of Set 10 | doha
# Processing Record 10 of Set 10 | aklavik
# Processing Record 11 of Set 10 | calabar
# Processing Record 12 of Set 10 | san alberto
# Processing Record 13 of Set 10 | saint-joseph
# Processing Record 14 of Set 10 | surami
# Processing Record 15 of Set 10 | malartic
# Processing Record 16 of Set 10 | yulara
# Processing Record 17 of Set 10 | santa flavia
# Processing Record 18 of Set 10 | ngukurr
# City not found. Skipping
# Processing Record 19 of Set 10 | koungheul
# Processing Record 20 of Set 10 | delta del tigre
# Processing Record 21 of Set 10 | vila
# Processing Record 22 of Set 10 | rawson
# Processing Record 23 of Set 10 | sao filipe
# Processing Record 24 of Set 10 | waipawa
# Processing Record 25 of Set 10 | kazalinsk
# City not found. Skipping
# Processing Record 26 of Set 10 | swan hill
# Processing Record 27 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 10 | wencheng
# Processing Record 29 of Set 10 | puerto escondido
# Processing Record 30 of Set 10 | caucaia
# Processing Record 31 of Set 10 | meulaboh
# Processing Record 32 of Set 10 | la ronge
# Processing Record 33 of Set 10 | martapura
# Processing Record 34 of Set 10 | salalah
# Processing Record 35 of Set 10 | borlange
# City not found. Skipping
# Processing Record 36 of Set 10 | manakara
# Processing Record 37 of Set 10 | sayyan
# Processing Record 38 of Set 10 | luang prabang
# Processing Record 39 of Set 10 | coquimbo
# Processing Record 40 of Set 10 | zhanaozen
# Processing Record 41 of Set 10 | qostanay
# Processing Record 42 of Set 10 | zhangzhou
# Processing Record 43 of Set 10 | kathmandu
# Processing Record 44 of Set 10 | barawe
# City not found. Skipping
# Processing Record 45 of Set 10 | butterworth
# Processing Record 46 of Set 10 | olafsvik
# Processing Record 47 of Set 10 | bohunovice
# Processing Record 48 of Set 10 | letlhakeng
# Processing Record 49 of Set 10 | neiafu
# Processing Record 50 of Set 10 | awjilah
# Processing Record 1 of Set 11 | spasskoye
# Processing Record 2 of Set 11 | pyay
# Processing Record 3 of Set 11 | dzerzhinsk
# Processing Record 4 of Set 11 | san quintin
# Processing Record 5 of Set 11 | buta
# Processing Record 6 of Set 11 | palana
# Processing Record 7 of Set 11 | urfa
# City not found. Skipping
# Processing Record 8 of Set 11 | mahon
# Processing Record 9 of Set 11 | victoria
# Processing Record 10 of Set 11 | kieta
# Processing Record 11 of Set 11 | bereda
# Processing Record 12 of Set 11 | vayalar
# Processing Record 13 of Set 11 | seydi
# Processing Record 14 of Set 11 | gardez
# Processing Record 15 of Set 11 | segezha
# Processing Record 16 of Set 11 | jonkoping
# Processing Record 17 of Set 11 | asau
# Processing Record 18 of Set 11 | capoterra
# Processing Record 19 of Set 11 | toowoomba
# Processing Record 20 of Set 11 | salisbury
# Processing Record 21 of Set 11 | nepa nagar
# Processing Record 22 of Set 11 | udomlya
# Processing Record 23 of Set 11 | sampit
# Processing Record 24 of Set 11 | necochea
# Processing Record 25 of Set 11 | berdigestyakh
# Processing Record 26 of Set 11 | axim
# Processing Record 27 of Set 11 | one hundred mile house
# City not found. Skipping
# Processing Record 28 of Set 11 | sentyabrskiy
# City not found. Skipping
# Processing Record 29 of Set 11 | krasnovishersk
# Processing Record 30 of Set 11 | broken hill
# Processing Record 31 of Set 11 | nouadhibou
# Processing Record 32 of Set 11 | ushtobe
# Processing Record 33 of Set 11 | savannakhet
# Processing Record 34 of Set 11 | angoche
# Processing Record 35 of Set 11 | buchanan
# Processing Record 36 of Set 11 | kalmunai
# Processing Record 37 of Set 11 | buariki
# City not found. Skipping
# Processing Record 38 of Set 11 | lima
# Processing Record 39 of Set 11 | maxixe
# Processing Record 40 of Set 11 | vilhena
# Processing Record 41 of Set 11 | sairang
# Processing Record 42 of Set 11 | gallup
# Processing Record 43 of Set 11 | kodar
# Processing Record 44 of Set 11 | hirara
# Processing Record 45 of Set 11 | tsiroanomandidy
# Processing Record 46 of Set 11 | barnstaple
# Processing Record 47 of Set 11 | mahibadhoo
# Processing Record 48 of Set 11 | pangnirtung
# Processing Record 49 of Set 11 | grand-santi
# Processing Record 50 of Set 11 | zhitikara
# City not found. Skipping
# Processing Record 1 of Set 12 | pirovskoye
# Processing Record 2 of Set 12 | andijon
# Processing Record 3 of Set 12 | stoyba
# City not found. Skipping
# Processing Record 4 of Set 12 | praya
# Processing Record 5 of Set 12 | luanda
# Processing Record 6 of Set 12 | bell ville
# Processing Record 7 of Set 12 | inuvik
# Processing Record 8 of Set 12 | peniche
# Processing Record 9 of Set 12 | tura
# Processing Record 10 of Set 12 | pasighat
# Processing Record 11 of Set 12 | pastavy
# Processing Record 12 of Set 12 | coatzintla
# Processing Record 13 of Set 12 | sackville
# Processing Record 14 of Set 12 | bitkine
# Processing Record 15 of Set 12 | sept-iles
# Processing Record 16 of Set 12 | nha trang
# Processing Record 17 of Set 12 | arys
# Processing Record 18 of Set 12 | matamoros
# Processing Record 19 of Set 12 | zhigansk
# Processing Record 20 of Set 12 | lapa
# Processing Record 21 of Set 12 | trofors
# Processing Record 22 of Set 12 | grand river south east
# City not found. Skipping
# Processing Record 23 of Set 12 | veraval
# Processing Record 24 of Set 12 | sao jose da coroa grande
# Processing Record 25 of Set 12 | airai
# Processing Record 26 of Set 12 | krutikha
# Processing Record 27 of Set 12 | temaraia
# City not found. Skipping
# Processing Record 28 of Set 12 | karaul
# City not found. Skipping
# Processing Record 29 of Set 12 | contamana
# Processing Record 30 of Set 12 | kindia
# Processing Record 31 of Set 12 | aasiaat
# Processing Record 32 of Set 12 | marawi
# Processing Record 33 of Set 12 | gemena
# Processing Record 34 of Set 12 | diglur
# Processing Record 35 of Set 12 | acajutla
# Processing Record 36 of Set 12 | abha
# Processing Record 37 of Set 12 | kamyaran
# Processing Record 38 of Set 12 | santa ines
# Processing Record 39 of Set 12 | whitehorse
# Processing Record 40 of Set 12 | maloshuyka
# City not found. Skipping
# Processing Record 41 of Set 12 | moree
# Processing Record 42 of Set 12 | qaqortoq
# Processing Record 43 of Set 12 | huangmei
# Processing Record 44 of Set 12 | the valley
# Processing Record 45 of Set 12 | yar-sale
# Processing Record 46 of Set 12 | general roca
# Processing Record 47 of Set 12 | oranjemund
# Processing Record 48 of Set 12 | saint combs
# City not found. Skipping
# Processing Record 49 of Set 12 | hohhot
# Processing Record 50 of Set 12 | batemans bay
# Processing Record 1 of Set 13 | ushirombo
# Processing Record 2 of Set 13 | kavali
# Processing Record 3 of Set 13 | porterville
# Processing Record 4 of Set 13 | xai-xai
# Processing Record 5 of Set 13 | havre-saint-pierre
# Processing Record 6 of Set 13 | stephenville
# Processing Record 7 of Set 13 | senanga
# Processing Record 8 of Set 13 | puerto del rosario
# Processing Record 9 of Set 13 | neryungri
# Processing Record 10 of Set 13 | hay river
# Processing Record 11 of Set 13 | homer
# Processing Record 12 of Set 13 | komsomolskiy
# Processing Record 13 of Set 13 | grindavik
# Processing Record 14 of Set 13 | svetlyy
# Processing Record 15 of Set 13 | zabolottya
# City not found. Skipping
# Processing Record 16 of Set 13 | ancud
# Processing Record 17 of Set 13 | ipixuna
# Processing Record 18 of Set 13 | huesca
# Processing Record 19 of Set 13 | kudahuvadhoo
# Processing Record 20 of Set 13 | meadow lake
# Processing Record 21 of Set 13 | creel
# Processing Record 22 of Set 13 | wuwei
# Processing Record 23 of Set 13 | severodvinsk
# Processing Record 24 of Set 13 | aksarka
# Processing Record 25 of Set 13 | loiza
# Processing Record 26 of Set 13 | lodja
# Processing Record 27 of Set 13 | marrakesh
# Processing Record 28 of Set 13 | kabo
# Processing Record 29 of Set 13 | mogadishu
# Processing Record 30 of Set 13 | kidal
# Processing Record 31 of Set 13 | wabana
# Processing Record 32 of Set 13 | mandalgovi
# Processing Record 33 of Set 13 | kagoro
# Processing Record 34 of Set 13 | sahrak
# City not found. Skipping
# Processing Record 35 of Set 13 | shadegan
# Processing Record 36 of Set 13 | bialogard
# Processing Record 37 of Set 13 | ixtapa
# Processing Record 38 of Set 13 | dong hoi
# Processing Record 39 of Set 13 | lolua
# City not found. Skipping
# Processing Record 40 of Set 13 | parati
# Processing Record 41 of Set 13 | saint-pierre
# Processing Record 42 of Set 13 | bor
# Processing Record 43 of Set 13 | matay
# Processing Record 44 of Set 13 | weinan
# Processing Record 45 of Set 13 | eureka
# Processing Record 46 of Set 13 | sakakah
# Processing Record 47 of Set 13 | vostok
# Processing Record 48 of Set 13 | saint-denis
# Processing Record 49 of Set 13 | palamos
# Processing Record 50 of Set 13 | saint anthony
# Processing Record 1 of Set 14 | sai buri
# Processing Record 2 of Set 14 | teruel
# Processing Record 3 of Set 14 | lardos
# Processing Record 4 of Set 14 | dawlatabad
# Processing Record 5 of Set 14 | along
# Processing Record 6 of Set 14 | siva
# Processing Record 7 of Set 14 | repatriacion
# Processing Record 8 of Set 14 | cibitoke
# Processing Record 9 of Set 14 | dir
# Processing Record 10 of Set 14 | udachnyy
# Processing Record 11 of Set 14 | sokolka
# Processing Record 12 of Set 14 | portland
# Processing Record 13 of Set 14 | puertollano
# Processing Record 14 of Set 14 | guatire
# Processing Record 15 of Set 14 | libato
# Processing Record 16 of Set 14 | zemio
# Processing Record 17 of Set 14 | candawaga
# City not found. Skipping
# Processing Record 18 of Set 14 | skalistyy
# City not found. Skipping
# Processing Record 19 of Set 14 | mungwi
# Processing Record 20 of Set 14 | tautira
# Processing Record 21 of Set 14 | margate
# Processing Record 22 of Set 14 | beira
# Processing Record 23 of Set 14 | ndele
# Processing Record 24 of Set 14 | aquiraz
# Processing Record 25 of Set 14 | araouane
# Processing Record 26 of Set 14 | girne
# Processing Record 27 of Set 14 | camabatela
# Processing Record 28 of Set 14 | california city
# Processing Record 29 of Set 14 | dapaong
# Processing Record 30 of Set 14 | biak
# Processing Record 31 of Set 14 | bay roberts
# Processing Record 32 of Set 14 | zelenoborskiy
# Processing Record 33 of Set 14 | enshi
# Processing Record 34 of Set 14 | vilyuysk
# Processing Record 35 of Set 14 | luneburg
# Processing Record 36 of Set 14 | aginskoye
# Processing Record 37 of Set 14 | mitsamiouli
# Processing Record 38 of Set 14 | yaan
# Processing Record 39 of Set 14 | lagoa vermelha
# Processing Record 40 of Set 14 | mizdah
# Processing Record 41 of Set 14 | balikpapan
# Processing Record 42 of Set 14 | sambava
# Processing Record 43 of Set 14 | cicero dantas
# Processing Record 44 of Set 14 | yangambi
# Processing Record 45 of Set 14 | port hardy
# Processing Record 46 of Set 14 | avera
# Processing Record 47 of Set 14 | goure
# Processing Record 48 of Set 14 | ballina
# Processing Record 49 of Set 14 | liptovsky hradok
# Processing Record 50 of Set 14 | berwick
# Processing Record 1 of Set 15 | boden
# Processing Record 2 of Set 15 | tabou
# Processing Record 3 of Set 15 | sola
# Processing Record 4 of Set 15 | yatou
# Processing Record 5 of Set 15 | casper
# Processing Record 6 of Set 15 | san juan bautista
# Processing Record 7 of Set 15 | chipinge
# Processing Record 8 of Set 15 | vallenar
# Processing Record 9 of Set 15 | moberly
# Processing Record 10 of Set 15 | benguela
# Processing Record 11 of Set 15 | lazurne
# Processing Record 12 of Set 15 | cuiluan
# Processing Record 13 of Set 15 | te anau
# Processing Record 14 of Set 15 | kholtoson
# Processing Record 15 of Set 15 | kiunga
# Processing Record 16 of Set 15 | manadhoo
# Processing Record 17 of Set 15 | paamiut
# Processing Record 18 of Set 15 | zachagansk
# City not found. Skipping
# Processing Record 19 of Set 15 | pochutla
# Processing Record 20 of Set 15 | labutta
# City not found. Skipping
# Processing Record 21 of Set 15 | de aar
# Processing Record 22 of Set 15 | peleduy
# Processing Record 23 of Set 15 | dubrovnik
# Processing Record 24 of Set 15 | najran
# Processing Record 25 of Set 15 | esso
# Processing Record 26 of Set 15 | salinopolis
# Processing Record 27 of Set 15 | maitum
# Processing Record 28 of Set 15 | korem
# Processing Record 29 of Set 15 | ayan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 663

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0  Puerto Ayora      EC  2021-07-24 18:34:03  -0.7393  -90.3518     82.36
# 1          Kaeo      NZ  2021-07-24 18:34:05 -35.1000  173.7833     55.33
# 2         Kapaa      US  2021-07-24 18:31:00  22.0752 -159.3190     80.58
# 3        Faanui      PF  2021-07-24 18:31:46 -16.4833 -151.7500     77.79
# 4     Jamestown      US  2021-07-24 18:34:08  42.0970  -79.2353     80.19
# 5      Saldanha      ZA  2021-07-24 18:34:09 -33.0117   17.9442     51.85
# 6  San Patricio      US  2021-07-24 18:34:10  28.0170  -97.5169     94.01
# 7      Cherskiy      RU  2021-07-24 18:34:11  68.7500  161.3000     45.01
# 8   East London      ZA  2021-07-24 18:31:48 -33.0153   27.9116     54.54
# 9        Pauini      BR  2021-07-24 18:34:13  -7.7136  -66.9764     97.72
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        81          15        8.99          few clouds
# 1        87          97       10.92     overcast clouds
# 2        84          90        4.00          light rain
# 3        71           3       13.85           clear sky
# 4        61          20        7.00          few clouds
# 5        69           7       11.03           clear sky
# 6        39           0       15.39           clear sky
# 7        74          99        3.47     overcast clouds
# 8        76           0        9.22           clear sky
# 9        26          21        2.68          few clouds

# %%
# Create CSV file of DF
csv_weather_file = "weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
